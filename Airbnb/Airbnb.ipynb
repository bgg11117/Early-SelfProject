# %% [markdown]
# # Short description (ranking 60/1463)
# '''
# An important characteristic of this competition is that there is a time cut-off between training and testing data -- training data end on 7/1/2014, and testing data start on that data. Moreover, the session informations are available only for the data points after 2014. This code used 4 classifiers: (1) XGB trained on all (training) data, (2) RandomForests trained on all data, (3) XGB classifier trained on recent (aka fresh) data only, and (4) RandomForests trained on all data only. The results from each clasifier formed the final prediction via weighted voting.
# '''

# %% [markdown]
# # Feature_extraction_sessions

# %%
import collections
import numpy as np
import pandas as pd
import datetime as dt
import scipy.stats as stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from xgboost.sklearn import XGBClassifier
# pylint: disable=fixme, no-member

# %%
def remove_rare_values_inplace(df_frame, column_list, threshold):
    """ Remove rare values to speed up computation.
    Args:
        df_frame -- A pandas data frame.
        column_list -- A list of columns.
        threshold -- The threshold, below which a value is removed.
    """
    insignificant_population = int(np.floor(threshold * len(df_frame)))
    for cat in column_list:
        freqs = collections.Counter(df_frame[cat])
        other = [i for i in freqs if freqs[i] < insignificant_population]
        for i in other:
            df_frame[cat].replace(i, 'other', inplace=True)

# %%
collections.Counter(sessions['action'])
# Out:
# Counter({-1: 79626,
#          '10': 3215,
#          '11': 716,
#          '12': 2209,
#          '15': 1053,
#          'about_us': 416,
#          'accept_decline': 2,
#          'account': 9040,
#          'acculynk_bin_check_failed': 1,
#          'acculynk_bin_check_success': 51,
#          'acculynk_load_pin_pad': 50,
#          'acculynk_pin_pad_error': 4,
#          'acculynk_pin_pad_inactive': 30,
#          'acculynk_pin_pad_success': 5,
#          'acculynk_session_obtained': 52,
#          'active': 188036,
#          'add_business_address_colorbox': 9,
#          'add_guest_colorbox': 7,
#          'add_guests': 60,
#          'add_note': 961,
#          'agree_terms_check': 10938,
#          'agree_terms_uncheck': 598,
#          'airbnb_picks': 278,
#          'airbrb': 3,
#          'ajax_check_dates': 52517,
#          'ajax_get_referrals_amt': 11306,
#          'ajax_get_results': 369,
#          'ajax_google_translate': 290,
#          'ajax_google_translate_description': 933,
#          'ajax_google_translate_reviews': 951,
#          'ajax_image_upload': 13570,
#          'ajax_ldp': 19,
#          'ajax_lwlb_contact': 33413,
#          'ajax_payout_edit': 714,
#          'ajax_payout_options_by_country': 685,
#          'ajax_payout_split_edit': 7,
#          'ajax_photo_widget': 8,
#          'ajax_photo_widget_form_iframe': 24442,
#          'ajax_price_and_availability': 175,
#          'ajax_referral_banner_experiment_type': 4922,
#          'ajax_referral_banner_type': 4460,
#          'ajax_refresh_subtotal': 487744,
#          'ajax_send_message': 21,
#          'ajax_special_offer_dates_available': 3,
#          'ajax_statsd': 1945,
#          'ajax_worth': 56,
#          'apply': 5,
#          'apply_code': 810,
#          'apply_coupon_click': 6223,
#          'apply_coupon_click_success': 329,
#          'apply_coupon_error': 5566,
#          'apply_coupon_error_type': 5550,
#          'apply_reservation': 10915,
#          'approve': 11,
#          'ask_question': 44063,
#          'at_checkpoint': 5170,
#          'authenticate': 42930,
#          'authorize': 1040,
#          'available': 8729,
#          'badge': 34,
#          'become_user': 180,
#          'book': 243,
#          'booking': 4,
#          'braintree_client_token': 120,
#          'business_travel': 14,
#          'calendar_tab_inner2': 42198,
#          'callback': 19132,
#          'campaigns': 105028,
#          'cancel': 583,
#          'cancellation_policies': 19262,
#          'cancellation_policy_click': 3461,
#          'change': 1116,
#          'change_availability': 47,
#          'change_currency': 606,
#          'change_default_payout': 9,
#          'change_password': 172,
#          'check': 120,
#          'city_count': 8,
#          'clear_reservation': 119,
#          'click': 25571,
#          'clickthrough': 238,
#          'collections': 124417,
#          'complete': 1133,
#          'complete_redirect': 4506,
#          'complete_status': 24674,
#          'concierge': 47,
#          'confirm_email': 58726,
#          'confirmation': 2,
#          'connect': 10114,
#          'contact_new': 1796,
#          'countries': 182,
#          'country_options': 155,
#          'coupon_code_click': 2947,
#          'coupon_field_focus': 7608,
#          'create': 155887,
#          'create_ach': 39,
#          'create_airbnb': 87,
#          'create_multiple': 2101,
#          'create_paypal': 47,
#          'currencies': 297,
#          'custom_recommended_destinations': 16541,
#          'dashboard': 152952,
#          'deactivate': 1,
#          'deactivated': 1,
#          'deauthorize': 1,
#          'decision_tree': 2744,
#          'delete': 5029,
#          'department': 417,
#          'departments': 246,
#          'desks': 1,
#          'destroy': 226,
#          'detect_fb_session': 49,
#          'disaster_action': 6,
#          'domains': 1532,
#          'edit': 109083,
#          'edit_verification': 33434,
#          'email_by_key': 8,
#          'email_itinerary_colorbox': 140,
#          'email_share': 319,
#          'email_wishlist': 388,
#          'endpoint_error': 4769,
#          'envoy_bank_details_redirect': 2,
#          'envoy_form': 8,
#          'events': 1,
#          'facebook_auto_login': 3984,
#          'faq': 9475,
#          'faq_category': 6598,
#          'faq_experiment_ids': 1092,
#          'feed': 11,
#          'forgot_password': 760,
#          'founders': 62,
#          'friend_listing': 2,
#          'friends': 804,
#          'friends_new': 476,
#          'glob': 1242,
#          'google_importer': 22,
#          'guarantee': 248,
#          'guest_billing_receipt': 50,
#          'guest_booked_elsewhere': 221,
#          'handle_vanity_url': 7921,
#          'hard_fallback_submit': 4,
#          'has_profile_pic': 18,
#          'header_userpic': 141830,
#          'home_safety_landing': 134,
#          'home_safety_terms': 31,
#          'hospitality': 83,
#          'hospitality_standards': 48,
#          'host_2013': 27,
#          'host_cancel': 1,
#          'host_summary': 2111,
#          'hosting_social_proof': 4368,
#          'how_it_works': 749,
#          'identity': 53631,
#          'image_order': 419,
#          'impressions': 27787,
#          'index': 843699,
#          'invalid_action': 139,
#          'issue': 865,
#          'itinerary': 1870,
#          'jumio': 321,
#          'jumio_redirect': 5156,
#          'jumio_token': 8686,
#          'kba': 7922,
#          'kba_update': 12693,
#          'languages_multiselect': 5405,
#          'life': 28,
#          'listing': 774,
#          'listings': 43656,
#          'load_more': 13,
#          'locale_from_host': 4,
#          'localization_settings': 5414,
#          'localized': 15,
#          'locations': 75,
#          'login': 4811,
#          'login_modal': 1977,
#          'lookup': 162041,
#          'manage_listing': 26618,
#          'maybe_information': 7,
#          'media_resources': 12,
#          'message': 4,
#          'message_to_host_change': 14224,
#          'message_to_host_focus': 21636,
#          'mobile_landing_page': 619,
#          'mobile_oauth_callback': 434,
#          'multi': 332,
#          'multi_message': 52,
#          'multi_message_attributes': 51,
#          'my': 11315,
#          'my_listings': 730,
#          'my_reservations': 553,
#          'new': 11108,
#          'new_host': 6,
#          'new_session': 69,
#          'notifications': 59392,
#          'nyan': 1,
#          'office_location': 163,
#          'onenight': 15,
#          'open_graph_setting': 7230,
#          'open_hard_fallback_modal': 10,
#          'other_hosting_reviews': 750,
#          'other_hosting_reviews_first': 31045,
#          'overview': 383,
#          'p4_refund_policy_terms': 370,
#          'p4_terms': 292,
#          'patch': 1578,
#          'pay': 2298,
#          'payment_instruments': 23573,
#          'payment_methods': 19800,
#          'payoneer_account_redirect': 45,
#          'payoneer_signup_complete': 21,
#          'payout_delete': 5,
#          'payout_preferences': 4569,
#          'payout_update': 469,
#          'pending': 16000,
#          'pending_tickets': 1272,
#          'personalize': 706824,
#          'phone_number_widget': 7326,
#          'phone_verification': 16,
#          'phone_verification_call_taking_too_long': 195,
#          'phone_verification_error': 1035,
#          'phone_verification_modal': 1582,
#          'phone_verification_number_submitted_for_call': 693,
#          'phone_verification_number_submitted_for_sms': 2966,
#          'phone_verification_number_sucessfully_submitted': 2467,
#          'phone_verification_phone_number_removed': 208,
#          'phone_verification_success': 2032,
#          'photography': 633,
#          'photography_update': 6,
#          'place_worth': 108,
#          'plaxo_cb': 1,
#          'popular': 2160,
#          'popular_listing': 93,
#          'populate_from_facebook': 9181,
#          'populate_help_dropdown': 15313,
#          'position': 974,
#          'preapproval': 2,
#          'press_content': 14,
#          'press_news': 52,
#          'press_release': 54,
#          'pricing': 7,
#          'print_confirmation': 69,
#          'privacy': 1943,
#          'profile_pic': 15819,
#          'push_notification_callback': 3341,
#          'qt2': 64651,
#          'qt_reply_v2': 8534,
#          'qt_with': 1793,
#          'questions': 11,
#          'rate': 508,
#          'reactivate': 1,
#          'read_policy_click': 3905,
#          'receipt': 459,
#          'recent_reservations': 2478,
#          'recommend': 377,
#          'recommendation_page': 2,
#          'recommendations': 30592,
#          'recommended_listings': 10003,
#          'redirect': 35,
#          'references': 11395,
#          'referrer_status': 4268,
#          'refund_guest_cancellation': 2,
#          'relationship': 189,
#          'remove_dashboard_alert': 817,
#          'rentals': 7,
#          'report': 2,
#          'reputation': 57,
#          'request_new_confirm_email': 7933,
#          'request_photography': 59,
#          'requested': 57034,
#          'requirements': 715,
#          'reservation': 38,
#          'reset_calendar': 2,
#          'respond': 11,
#          'rest-of-world': 2,
#          'revert_to_admin': 1,
#          'review_page': 564,
#          'reviews': 320591,
#          'reviews_new': 5827,
#          'salute': 318,
#          'sandy': 2,
#          'satisfy': 9,
#          'search': 536057,
#          'search_results': 725226,
#          'set_default': 21,
#          'set_minimum_payout_amount': 1,
#          'set_password': 1572,
#          'set_user': 7012,
#          'settings': 16766,
#          'show': 2768278,
#          'show_code': 259,
#          'show_personalize': 50434,
#          'signature': 1817,
#          'signed_out_modal': 1058,
#          'signup_login': 8408,
#          'signup_modal': 1831,
#          'signup_weibo': 10,
#          'signup_weibo_referral': 90,
#          'similar_listings': 364624,
#          'similar_listings_v2': 168788,
#          'sldf': 1,
#          'slideshow': 40,
#          'social': 55,
#          'social-media': 7,
#          'social_connections': 339000,
#          'south-america': 2,
#          'southern-europe': 4,
#          'special_offer': 2,
#          'spoken_languages': 1475,
#          'status': 4480,
#          'stpcv': 2,
#          'sublets': 31,
#          'submit_contact': 241,
#          'support_phone_numbers': 20,
#          'supported': 1275,
#          'sync': 5,
#          'tell_a_friend': 3305,
#          'terms': 1946,
#          'terms_and_conditions': 329,
#          'this_hosting_reviews': 3869,
#          'this_hosting_reviews_3000': 1376,
#          'toggle_archived_thread': 380,
#          'toggle_availability': 3,
#          'toggle_starred_thread': 206,
#          'top_destinations': 1279,
#          'tos_2014': 2,
#          'tos_confirm': 2952,
#          'track_activity': 6,
#          'track_page_view': 81117,
#          'transaction_history': 2033,
#          'transaction_history_paginated': 1130,
#          'travel': 5,
#          'travel_plans_current': 38195,
#          'travel_plans_previous': 675,
#          'trust': 743,
#          'unavailabilities': 78317,
#          'united-states': 30,
#          'unread': 40,
#          'unsubscribe': 2,
#          'update': 365130,
#          'update_cached': 835,
#          'update_country_of_residence': 59,
#          'update_friends_display': 171,
#          'update_hide_from_search_engines': 226,
#          'update_message': 1,
#          'update_notifications': 1316,
#          'update_reservation_requirements': 55,
#          'upload': 762,
#          'uptodate': 3342,
#          'use_mobile_site': 2,
#          'verify': 21372,
#          'view': 13159,
#          'views': 22,
#          'views_campaign': 2,
#          'views_campaign_rules': 2,
#          'webcam_upload': 815,
#          'weibo_signup_referral_finish': 45,
#          'why_host': 180,
#          'widget': 75,
#          'wishlists': 1,
#          'zendesk_login_jwt': 24})

# %%
INDEX_COLUMN = 'user_id'
SECS_ELAPSED_NUMERICAL = 'secs_elapsed'
CATEGORICAL_FEATURES = ['action', 'action_type', 'action_detail', 'device_type']
SESSSIONS_CSV_FILE = 'data/airbnb/sessions.csv'
OUTPUT_TO_CSV_FILE = 'data/airbnb/session_features.csv'  # Results will be saved here.

# A parameter to speed-up computation. Categorical values that appear
# less than the threshold will be removed.
VALUE_THRESHOLD = 0.005

# %%
def extract_frequency_counts(pd_frame, column_list):
    """ Extract frequency counts from pd_frame.

    For each index (that correspond to a user) this method will count the
    number of times that C == Ci, where C is a column in column_list, and Ci
    is a unique value of that column. The arg olumn_list is assumed
    to contain categorical columns.

    Args:
        df_frame -- A pandas data frame.
        column_list -- A list of columns.

    Returns:
        A pandas DataFrame, containing frequency counts.
    """
    df_extracted_sessions = []
    for col in column_list:
        for val in set(pd_frame[col]):
            print 'Extracting frequency counts for (%s == %s)' % (col, val)
            tmp_df = pd_frame.groupby(pd_frame.index).apply(
                lambda group, x=col, y=val: np.sum(group[x] == y))
            tmp_df.name = '%s=%s' % (col, val)
            df_extracted_sessions.append(tmp_df)
    frequency_counts = pd.concat(df_extracted_sessions, axis=1)
    return frequency_counts

# %%
sessions.head()
# Out:
#                     action action_type        action_detail      device_type  \
# user_id
# d1mm9tcy42          lookup          -1                   -1  Windows Desktop
# d1mm9tcy42  search_results       click  view_search_results  Windows Desktop
# d1mm9tcy42          lookup          -1                   -1  Windows Desktop
# d1mm9tcy42  search_results       click  view_search_results  Windows Desktop
# d1mm9tcy42          lookup          -1                   -1  Windows Desktop
#
#             secs_elapsed
# user_id
# d1mm9tcy42         319.0
# d1mm9tcy42       67753.0
# d1mm9tcy42         301.0
# d1mm9tcy42       22141.0
# d1mm9tcy42         435.0

# %%
set(sessions['device_type'])
# Out:
# {'-unknown-',
#  'Android App Unknown Phone/Tablet',
#  'Android Phone',
#  'Mac Desktop',
#  'Tablet',
#  'Windows Desktop',
#  'iPad Tablet',
#  'iPhone',
#  'other'}

# %%
A = list(sessions.groupby(sessions.index))
A[0]
# Out:
# ('00023iyk9l',
#                             action   action_type                action_detail  \
#  user_id
#  00023iyk9l                  index          view          view_search_results
#  00023iyk9l              dashboard          view                    dashboard
#  00023iyk9l         header_userpic          data               header_userpic
#  00023iyk9l              dashboard          view                    dashboard
#  00023iyk9l                  other         other                        other
#  00023iyk9l                     -1  message_post                 message_post
#  00023iyk9l                  other         other                        other
#  00023iyk9l              requested          view                        other
#  00023iyk9l              requested          view                        other
#  00023iyk9l              requested          view                        other
#  00023iyk9l              requested          view                        other
#  00023iyk9l              requested          view                        other
#  00023iyk9l                  other          view                        other
#  00023iyk9l                  other          view                        other
#  00023iyk9l                   show          view                           p3
#  00023iyk9l                   show            -1                           -1
#  00023iyk9l  ajax_refresh_subtotal         click  change_trip_characteristics
#  00023iyk9l                   show          view                           p3
#  00023iyk9l       similar_listings          data             similar_listings
#  00023iyk9l          confirm_email         click           confirm_email_link
#  00023iyk9l                   show          view                           p3
#  00023iyk9l            personalize          data      wishlist_content_update
#  00023iyk9l                   show            -1                           -1
#  00023iyk9l              dashboard          view                    dashboard
#  00023iyk9l         header_userpic          data               header_userpic
#  00023iyk9l              dashboard          view                    dashboard
#  00023iyk9l            personalize          data      wishlist_content_update
#  00023iyk9l       similar_listings          data             similar_listings
#  00023iyk9l                   show          view                           p3
#  00023iyk9l                  index          view          view_search_results
#  00023iyk9l                  index          view          view_search_results
#  00023iyk9l                   show          view                           p3
#  00023iyk9l       similar_listings          data             similar_listings
#  00023iyk9l  ajax_refresh_subtotal         click  change_trip_characteristics
#  00023iyk9l                   show            -1                           -1
#  00023iyk9l            personalize          data      wishlist_content_update
#  00023iyk9l                   show          view                           p3
#  00023iyk9l         search_results         click          view_search_results
#  00023iyk9l                  index          view          view_search_results
#  00023iyk9l            personalize          data      wishlist_content_update
#
#              device_type  secs_elapsed
#  user_id
#  00023iyk9l  Mac Desktop       20438.0
#  00023iyk9l  Mac Desktop         787.0
#  00023iyk9l  Mac Desktop         850.0
#  00023iyk9l  Mac Desktop         934.0
#  00023iyk9l  Mac Desktop          -1.0
#  00023iyk9l  Mac Desktop      129817.0
#  00023iyk9l  Mac Desktop           0.0
#  00023iyk9l  Mac Desktop        1904.0
#  00023iyk9l  Mac Desktop        1618.0
#  00023iyk9l  Mac Desktop       32081.0
#  00023iyk9l  Mac Desktop         702.0
#  00023iyk9l  Mac Desktop        3827.0
#  00023iyk9l  Mac Desktop         474.0
#  00023iyk9l  Mac Desktop         992.0
#  00023iyk9l  Mac Desktop       43110.0
#  00023iyk9l  Mac Desktop         820.0
#  00023iyk9l  Mac Desktop         836.0
#  00023iyk9l  Mac Desktop         395.0
#  00023iyk9l  Mac Desktop         155.0
#  00023iyk9l       iPhone      567165.0
#  00023iyk9l  Mac Desktop         369.0
#  00023iyk9l  Mac Desktop           6.0
#  00023iyk9l  Mac Desktop          45.0
#  00023iyk9l       iPhone        2331.0
#  00023iyk9l       iPhone        2348.0
#  00023iyk9l       iPhone         410.0
#  00023iyk9l  Mac Desktop         922.0
#  00023iyk9l  Mac Desktop          81.0
#  00023iyk9l  Mac Desktop        3813.0
#  00023iyk9l  Mac Desktop        2173.0
#  00023iyk9l  Mac Desktop        9938.0
#  00023iyk9l  Mac Desktop         182.0
#  00023iyk9l  Mac Desktop          94.0
#  00023iyk9l  Mac Desktop         611.0
#  00023iyk9l  Mac Desktop         112.0
#  00023iyk9l  Mac Desktop         820.0
#  00023iyk9l  Mac Desktop       12727.0
#  00023iyk9l  Mac Desktop       22079.0
#  00023iyk9l  Mac Desktop         163.0
#  00023iyk9l  Mac Desktop        1767.0  )

# %%
A[0][1].head()
# Out:
#                     action action_type        action_detail  device_type  \
# user_id
# 00023iyk9l           index        view  view_search_results  Mac Desktop
# 00023iyk9l       dashboard        view            dashboard  Mac Desktop
# 00023iyk9l  header_userpic        data       header_userpic  Mac Desktop
# 00023iyk9l       dashboard        view            dashboard  Mac Desktop
# 00023iyk9l           other       other                other  Mac Desktop
#
#             secs_elapsed
# user_id
# 00023iyk9l       20438.0
# 00023iyk9l         787.0
# 00023iyk9l         850.0
# 00023iyk9l         934.0
# 00023iyk9l          -1.0

# %%
np.sum(A[0][1]['device_type']=='Mac Desktop')
# Out:
# 36

# %%
def extract_distribution_stats(pd_frame, numerical_col):
    """ Extract simple distribution statistics from a numerical column.

    Args:
        df_frame -- A pandas data frame.
        numerical_col -- A column in pd_frame that contains numerical values.

    Returns:
        A pandas DataFrame, containing simple satistics for col_name.
    """
    tmp_df = pd_frame[numerical_col].groupby(pd_frame.index).aggregate(
        [np.mean, np.std, np.median, stats.skew])
    tmp_df.columns = ['%s_%s'% (numerical_col, i) for i in tmp_df.columns]
    return tmp_df

# %%
SECS_ELAPSED_NUMERICAL
# Out:
# 'secs_elapsed'

# %%
# Load basic training and testing data, from CSV file.
sessions = pd.read_csv(SESSSIONS_CSV_FILE)
sessions.set_index(INDEX_COLUMN, inplace=True)
sessions.fillna(-1, inplace=True)

# %%
# Extract features from sessions.
remove_rare_values_inplace(sessions, CATEGORICAL_FEATURES, VALUE_THRESHOLD)
frequency_counts = extract_frequency_counts(sessions, CATEGORICAL_FEATURES)
simple_stats = extract_distribution_stats(sessions, SECS_ELAPSED_NUMERICAL)
# Out:
# Extracting frequency counts for (action == show)
# Extracting frequency counts for (action == similar_listings)
# Extracting frequency counts for (action == index)
# Extracting frequency counts for (action == search_results)
# Extracting frequency counts for (action == confirm_email)
# Extracting frequency counts for (action == create)
# Extracting frequency counts for (action == header_userpic)
# Extracting frequency counts for (action == lookup)
# Extracting frequency counts for (action == collections)
# Extracting frequency counts for (action == requested)
# Extracting frequency counts for (action == qt2)
# Extracting frequency counts for (action == personalize)
# Extracting frequency counts for (action == update)
# Extracting frequency counts for (action == track_page_view)
# Extracting frequency counts for (action == notifications)
# Extracting frequency counts for (action == active)
# Extracting frequency counts for (action == similar_listings_v2)
# Extracting frequency counts for (action == identity)
# Extracting frequency counts for (action == social_connections)
# Extracting frequency counts for (action == unavailabilities)
# Extracting frequency counts for (action == campaigns)
# Extracting frequency counts for (action == search)
# Extracting frequency counts for (action == ajax_refresh_subtotal)
# Extracting frequency counts for (action == edit)
# Extracting frequency counts for (action == reviews)
# Extracting frequency counts for (action == dashboard)
# Extracting frequency counts for (action == other)
# Extracting frequency counts for (action == -1)
# Extracting frequency counts for (action_type == -unknown-)
# Extracting frequency counts for (action_type == submit)
# Extracting frequency counts for (action_type == other)
# Extracting frequency counts for (action_type == message_post)
# Extracting frequency counts for (action_type == data)
# Extracting frequency counts for (action_type == click)
# Extracting frequency counts for (action_type == -1)
# Extracting frequency counts for (action_type == view)
# Extracting frequency counts for (action_detail == user_wishlists)
# Extracting frequency counts for (action_detail == create_user)
# Extracting frequency counts for (action_detail == confirm_email_link)
# Extracting frequency counts for (action_detail == change_trip_characteristics)
# Extracting frequency counts for (action_detail == similar_listings)
# Extracting frequency counts for (action_detail == message_post)
# Extracting frequency counts for (action_detail == view_search_results)
# Extracting frequency counts for (action_detail == wishlist_content_update)
# Extracting frequency counts for (action_detail == -unknown-)
# Extracting frequency counts for (action_detail == header_userpic)
# Extracting frequency counts for (action_detail == listing_reviews)
# Extracting frequency counts for (action_detail == message_thread)
# Extracting frequency counts for (action_detail == user_social_connections)
# Extracting frequency counts for (action_detail == user_profile)
# Extracting frequency counts for (action_detail == edit_profile)
# Extracting frequency counts for (action_detail == update_listing)
# Extracting frequency counts for (action_detail == p3)
# Extracting frequency counts for (action_detail == contact_host)
# Extracting frequency counts for (action_detail == dashboard)
# Extracting frequency counts for (action_detail == unavailable_dates)
# Extracting frequency counts for (action_detail == other)
# Extracting frequency counts for (action_detail == -1)
# Extracting frequency counts for (device_type == Windows Desktop)
# Extracting frequency counts for (device_type == Tablet)
# Extracting frequency counts for (device_type == -unknown-)
# Extracting frequency counts for (device_type == Android App Unknown Phone/Tablet)
# Extracting frequency counts for (device_type == Mac Desktop)
# Extracting frequency counts for (device_type == other)
# Extracting frequency counts for (device_type == iPhone)
# Extracting frequency counts for (device_type == iPad Tablet)
# Extracting frequency counts for (device_type == Android Phone)

# %%
# Save new data.
session_data = pd.concat((frequency_counts, simple_stats), axis=1)
session_data.fillna(-1, inplace=True)
#session_data.to_csv(OUTPUT_TO_CSV_FILE)

# %%
session_data.head(10)
# Out:
#             action=show  action=similar_listings  action=index  \
# user_id
# 00023iyk9l            9                        3             4
# 0010k6l0om           20                        0             5
# 001wyh0pz8            6                        0             2
# 0028jgx1x1           15                        0             0
# 002qnbzfs5          232                        0           115
# 0031awlkjq            0                        0             2
# 0035hobuyj           47                       12            23
# 00378ocvlh            7                        0             0
# 00389675gq           33                       17            21
# 003iamz20l           60                        0             0
#
#             action=search_results  action=confirm_email  action=create  \
# user_id
# 00023iyk9l                      1                     1              0
# 0010k6l0om                      8                     0              0
# 001wyh0pz8                      0                     0              1
# 0028jgx1x1                      0                     0              1
# 002qnbzfs5                      0                     1             21
# 0031awlkjq                      0                     0              0
# 0035hobuyj                    180                     1              1
# 00378ocvlh                      0                     0              1
# 00389675gq                      6                     0              2
# 003iamz20l                      0                     0              1
#
#             action=header_userpic  action=lookup  action=collections  \
# user_id
# 00023iyk9l                      2              0                   0
# 0010k6l0om                      1              0                   0
# 001wyh0pz8                      0              0                   4
# 0028jgx1x1                      0              0                   0
# 002qnbzfs5                      2              0                   0
# 0031awlkjq                      1              0                   0
# 0035hobuyj                      2            148                   0
# 00378ocvlh                      1              0                   0
# 00389675gq                      2              0                   3
# 003iamz20l                      0              0                   0
#
#             action=requested        ...          \
# user_id                             ...
# 00023iyk9l                 5        ...
# 0010k6l0om                 0        ...
# 001wyh0pz8                 0        ...
# 0028jgx1x1                 0        ...
# 002qnbzfs5                 0        ...
# 0031awlkjq                 0        ...
# 0035hobuyj                 0        ...
# 00378ocvlh                 0        ...
# 00389675gq                 0        ...
# 003iamz20l                 0        ...
#
#             device_type=Android App Unknown Phone/Tablet  \
# user_id
# 00023iyk9l                                             0
# 0010k6l0om                                             0
# 001wyh0pz8                                            90
# 0028jgx1x1                                             0
# 002qnbzfs5                                             0
# 0031awlkjq                                             0
# 0035hobuyj                                             0
# 00378ocvlh                                             0
# 00389675gq                                             0
# 003iamz20l                                             0
#
#             device_type=Mac Desktop  device_type=other  device_type=iPhone  \
# user_id
# 00023iyk9l                       36                  0                   4
# 0010k6l0om                       63                  0                   0
# 001wyh0pz8                        0                  0                   0
# 0028jgx1x1                        0                  0                   0
# 002qnbzfs5                        0                  0                 775
# 0031awlkjq                        0                  0                   8
# 0035hobuyj                      489                  0                   0
# 00378ocvlh                       75                  0                   0
# 00389675gq                        0                  0                   0
# 003iamz20l                        0                  0                   0
#
#             device_type=iPad Tablet  device_type=Android Phone  \
# user_id
# 00023iyk9l                        0                          0
# 0010k6l0om                        0                          0
# 001wyh0pz8                        0                          0
# 0028jgx1x1                        0                          1
# 002qnbzfs5                        0                          0
# 0031awlkjq                        0                          0
# 0035hobuyj                        0                          0
# 00378ocvlh                        0                          0
# 00389675gq                        0                         17
# 003iamz20l                      163                          0
#
#             secs_elapsed_mean  secs_elapsed_std  secs_elapsed_median  \
# user_id
# 00023iyk9l       21697.375000      91120.253083                843.0
# 0010k6l0om        9310.190476      22598.464587                847.0
# 001wyh0pz8        3144.044444       6541.232094               1104.0
# 0028jgx1x1        9580.935484      17791.437472                489.0
# 002qnbzfs5        8221.899873      58074.501937                498.0
# 0031awlkjq        4946.625000       8167.051416               1197.0
# 0035hobuyj       11706.889571      61264.809869                865.0
# 00378ocvlh       24362.173333      91144.438800               2157.0
# 00389675gq       14721.525424      41217.016461                959.0
# 003iamz20l        9756.042945      29152.050769                378.0
#
#             secs_elapsed_skew
# user_id
# 00023iyk9l           5.604319
# 0010k6l0om           3.550714
# 001wyh0pz8           4.913634
# 0028jgx1x1           2.864292
# 002qnbzfs5          19.436206
# 0031awlkjq           1.722653
# 0035hobuyj          16.056027
# 00378ocvlh           5.531566
# 00389675gq           5.361414
# 003iamz20l           7.411174
#
# [10 rows x 71 columns]

# %%
session_data.shape
# Out:
# (135483, 71)

# %% [markdown]
# # Data_preparation

# %%
LABEL = 'country_destination'
CATEGORICAL_FEATURES = ['affiliate_channel', 'affiliate_provider',
                        'first_affiliate_tracked', 'first_browser',
                        'first_device_type', 'gender', 'language', 'signup_app',
                        'signup_method', 'signup_flow']

DATE_FORMAT = '%Y-%m-%d'                # Expected format for date.
ACCOUNT_DATE = 'date_account_created'   # Date column that will be exploited.
ACCOUNT_DATE_YEAR = '%s_%s' % (ACCOUNT_DATE, 'year')
ACCOUNT_DATE_MONTH = '%s_%s' % (ACCOUNT_DATE, 'month')
UNUSED_DATE_COLUMNS = ['timestamp_first_active', 'date_first_booking']

TRAIN_DATA_BASIC = 'data/airbnb/train_users.csv'
TEST_DATA_BASIC = 'data/airbnb/test_users.csv'
SESSION_DATA = 'data/airbnb/session_features.csv'
TRAINING_FINAL_CSV_FILE = 'data/airbnb/training_features.csv'
TESTING_FINAL_CSV_FILE = 'data/airbnb/testing_features.csv'
LABELS_FINAL_CSV_FILE = 'data/airbnb/labels.csv'

# A parameter to speed-up computation. Categorical values that appear
# less than the threshold will be removed.
VALUE_THRESHOLD = 0.001

# %%
def _parse_date(date_str, format_str):
    """ Extract features from the data_account_creted column.
    Warning: There is strong dependency between this method and the method
    replace_dates_inplace.
    Args:
        date_str -- A string containing a date value.
        str_format -- The format of the string date.
    Returns:
        A list of 4 values containing the extracted [year, month, day, weekend].
    """
    time_dt = dt.datetime.strptime(date_str, format_str)
    return [time_dt.year, time_dt.month, time_dt.day, time_dt.weekday()]


def extract_dates_inplace(features, date_column):
    """ Extract from the date-columns, year, month, and other numericals.
    Warning: There is strong dependency between this method and _parse_date.
    """
    extracted_vals = np.vstack(features[date_column].apply(
        (lambda x: _parse_date(x, DATE_FORMAT))))
    for i, period in enumerate(['year', 'month', 'day', 'weekday']):
        features['%s_%s' % (date_column, period)] = extracted_vals[:, i]
    features.drop(date_column, inplace=True, axis=1)

# %%
def apply_one_hot_encoding(pd_frame, column_list):
    """ Apply One-Hot-Encoding to pd_frame's categorical columns.
    Args:
        df_frame -- A pandas data frame.
        column_list -- A list of categorical columns, in df_frame.
    Returns:
        A pandas dataframe where the colums in column_list have been replaced
            by one-hot-encoded-columns.
    """
    new_column_list = []
    for col in column_list:
        tmp = pd.get_dummies(pd_frame[col], prefix=col)
        new_column_list.append(tmp)
    new_pd_frame = pd.concat(new_column_list+[pd_frame], axis=1)
    new_pd_frame.drop(column_list, inplace=True, axis=1)
    return new_pd_frame

# %%
new_column_list = []
for col in CATEGORICAL_FEATURES:
    tmp = pd.get_dummies(features[col], prefix=col)
    print tmp.head()
    print tmp.dtypes
    print type(tmp)
    new_column_list.append(tmp)
new_pd_frame = pd.concat(new_column_list+[features], axis=1)
new_pd_frame.drop(CATEGORICAL_FEATURES, inplace=True, axis=1)
new_pd_frame.head()
# Out:
#             affiliate_channel_api  affiliate_channel_content  \
# id
# gxn3p5htnn                      0                          0
# 820tgsjxq7                      0                          0
# 4ft3gnwmtx                      0                          0
# bjjt8pjhuk                      0                          0
# 87mebub9p4                      0                          0
#
#             affiliate_channel_direct  affiliate_channel_other  \
# id
# gxn3p5htnn                         1                        0
# 820tgsjxq7                         0                        0
# 4ft3gnwmtx                         1                        0
# bjjt8pjhuk                         1                        0
# 87mebub9p4                         1                        0
#
#             affiliate_channel_remarketing  affiliate_channel_sem-brand  \
# id
# gxn3p5htnn                              0                            0
# 820tgsjxq7                              0                            0
# 4ft3gnwmtx                              0                            0
# bjjt8pjhuk                              0                            0
# 87mebub9p4                              0                            0
#
#             affiliate_channel_sem-non-brand  affiliate_channel_seo
# id
# gxn3p5htnn                                0                      0
# 820tgsjxq7                                0                      1
# 4ft3gnwmtx                                0                      0
# bjjt8pjhuk                                0                      0
# 87mebub9p4                                0                      0
# affiliate_channel_api              uint8
# affiliate_channel_content          uint8
# affiliate_channel_direct           uint8
# affiliate_channel_other            uint8
# affiliate_channel_remarketing      uint8
# affiliate_channel_sem-brand        uint8
# affiliate_channel_sem-non-brand    uint8
# affiliate_channel_seo              uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             affiliate_provider_bing  affiliate_provider_craigslist  \
# id
# gxn3p5htnn                        0                              0
# 820tgsjxq7                        0                              0
# 4ft3gnwmtx                        0                              0
# bjjt8pjhuk                        0                              0
# 87mebub9p4                        0                              0
#
#             affiliate_provider_direct  affiliate_provider_facebook  \
# id
# gxn3p5htnn                          1                            0
# 820tgsjxq7                          0                            0
# 4ft3gnwmtx                          1                            0
# bjjt8pjhuk                          1                            0
# 87mebub9p4                          1                            0
#
#             affiliate_provider_facebook-open-graph  affiliate_provider_google  \
# id
# gxn3p5htnn                                       0                          0
# 820tgsjxq7                                       0                          1
# 4ft3gnwmtx                                       0                          0
# bjjt8pjhuk                                       0                          0
# 87mebub9p4                                       0                          0
#
#             affiliate_provider_gsp  affiliate_provider_meetup  \
# id
# gxn3p5htnn                       0                          0
# 820tgsjxq7                       0                          0
# 4ft3gnwmtx                       0                          0
# bjjt8pjhuk                       0                          0
# 87mebub9p4                       0                          0
#
#             affiliate_provider_other  affiliate_provider_padmapper  \
# id
# gxn3p5htnn                         0                             0
# 820tgsjxq7                         0                             0
# 4ft3gnwmtx                         0                             0
# bjjt8pjhuk                         0                             0
# 87mebub9p4                         0                             0
#
#             affiliate_provider_vast  affiliate_provider_yahoo
# id
# gxn3p5htnn                        0                         0
# 820tgsjxq7                        0                         0
# 4ft3gnwmtx                        0                         0
# bjjt8pjhuk                        0                         0
# 87mebub9p4                        0                         0
# affiliate_provider_bing                   uint8
# affiliate_provider_craigslist             uint8
# affiliate_provider_direct                 uint8
# affiliate_provider_facebook               uint8
# affiliate_provider_facebook-open-graph    uint8
# affiliate_provider_google                 uint8
# affiliate_provider_gsp                    uint8
# affiliate_provider_meetup                 uint8
# affiliate_provider_other                  uint8
# affiliate_provider_padmapper              uint8
# affiliate_provider_vast                   uint8
# affiliate_provider_yahoo                  uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             first_affiliate_tracked_-1  first_affiliate_tracked_linked  \
# id
# gxn3p5htnn                           0                               0
# 820tgsjxq7                           0                               0
# 4ft3gnwmtx                           0                               0
# bjjt8pjhuk                           0                               0
# 87mebub9p4                           0                               0
#
#             first_affiliate_tracked_marketing  first_affiliate_tracked_omg  \
# id
# gxn3p5htnn                                  0                            0
# 820tgsjxq7                                  0                            0
# 4ft3gnwmtx                                  0                            0
# bjjt8pjhuk                                  0                            0
# 87mebub9p4                                  0                            0
#
#             first_affiliate_tracked_other  first_affiliate_tracked_product  \
# id
# gxn3p5htnn                              0                                0
# 820tgsjxq7                              0                                0
# 4ft3gnwmtx                              0                                0
# bjjt8pjhuk                              0                                0
# 87mebub9p4                              0                                0
#
#             first_affiliate_tracked_tracked-other  \
# id
# gxn3p5htnn                                      0
# 820tgsjxq7                                      0
# 4ft3gnwmtx                                      0
# bjjt8pjhuk                                      0
# 87mebub9p4                                      0
#
#             first_affiliate_tracked_untracked
# id
# gxn3p5htnn                                  1
# 820tgsjxq7                                  1
# 4ft3gnwmtx                                  1
# bjjt8pjhuk                                  1
# 87mebub9p4                                  1
# first_affiliate_tracked_-1               uint8
# first_affiliate_tracked_linked           uint8
# first_affiliate_tracked_marketing        uint8
# first_affiliate_tracked_omg              uint8
# first_affiliate_tracked_other            uint8
# first_affiliate_tracked_product          uint8
# first_affiliate_tracked_tracked-other    uint8
# first_affiliate_tracked_untracked        uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             first_browser_-unknown-  first_browser_Android Browser  \
# id
# gxn3p5htnn                        0                              0
# 820tgsjxq7                        0                              0
# 4ft3gnwmtx                        0                              0
# bjjt8pjhuk                        0                              0
# 87mebub9p4                        0                              0
#
#             first_browser_Chrome  first_browser_Chrome Mobile  \
# id
# gxn3p5htnn                     1                            0
# 820tgsjxq7                     1                            0
# 4ft3gnwmtx                     0                            0
# bjjt8pjhuk                     0                            0
# 87mebub9p4                     1                            0
#
#             first_browser_Firefox  first_browser_IE  \
# id
# gxn3p5htnn                      0                 0
# 820tgsjxq7                      0                 0
# 4ft3gnwmtx                      0                 1
# bjjt8pjhuk                      1                 0
# 87mebub9p4                      0                 0
#
#             first_browser_Mobile Safari  first_browser_Safari  \
# id
# gxn3p5htnn                            0                     0
# 820tgsjxq7                            0                     0
# 4ft3gnwmtx                            0                     0
# bjjt8pjhuk                            0                     0
# 87mebub9p4                            0                     0
#
#             first_browser_other
# id
# gxn3p5htnn                    0
# 820tgsjxq7                    0
# 4ft3gnwmtx                    0
# bjjt8pjhuk                    0
# 87mebub9p4                    0
# first_browser_-unknown-          uint8
# first_browser_Android Browser    uint8
# first_browser_Chrome             uint8
# first_browser_Chrome Mobile      uint8
# first_browser_Firefox            uint8
# first_browser_IE                 uint8
# first_browser_Mobile Safari      uint8
# first_browser_Safari             uint8
# first_browser_other              uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             first_device_type_Android Phone  first_device_type_Android Tablet  \
# id
# gxn3p5htnn                                0                                 0
# 820tgsjxq7                                0                                 0
# 4ft3gnwmtx                                0                                 0
# bjjt8pjhuk                                0                                 0
# 87mebub9p4                                0                                 0
#
#             first_device_type_Desktop (Other)  first_device_type_Mac Desktop  \
# id
# gxn3p5htnn                                  0                              1
# 820tgsjxq7                                  0                              1
# 4ft3gnwmtx                                  0                              0
# bjjt8pjhuk                                  0                              1
# 87mebub9p4                                  0                              1
#
#             first_device_type_Other/Unknown  \
# id
# gxn3p5htnn                                0
# 820tgsjxq7                                0
# 4ft3gnwmtx                                0
# bjjt8pjhuk                                0
# 87mebub9p4                                0
#
#             first_device_type_Windows Desktop  first_device_type_iPad  \
# id
# gxn3p5htnn                                  0                       0
# 820tgsjxq7                                  0                       0
# 4ft3gnwmtx                                  1                       0
# bjjt8pjhuk                                  0                       0
# 87mebub9p4                                  0                       0
#
#             first_device_type_iPhone  first_device_type_other
# id
# gxn3p5htnn                         0                        0
# 820tgsjxq7                         0                        0
# 4ft3gnwmtx                         0                        0
# bjjt8pjhuk                         0                        0
# 87mebub9p4                         0                        0
# first_device_type_Android Phone      uint8
# first_device_type_Android Tablet     uint8
# first_device_type_Desktop (Other)    uint8
# first_device_type_Mac Desktop        uint8
# first_device_type_Other/Unknown      uint8
# first_device_type_Windows Desktop    uint8
# first_device_type_iPad               uint8
# first_device_type_iPhone             uint8
# first_device_type_other              uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             gender_-unknown-  gender_FEMALE  gender_MALE  gender_OTHER
# id
# gxn3p5htnn                 1              0            0             0
# 820tgsjxq7                 0              0            1             0
# 4ft3gnwmtx                 0              1            0             0
# bjjt8pjhuk                 0              1            0             0
# 87mebub9p4                 1              0            0             0
# gender_-unknown-    uint8
# gender_FEMALE       uint8
# gender_MALE         uint8
# gender_OTHER        uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             language_de  language_en  language_es  language_fr  language_it  \
# id
# gxn3p5htnn            0            1            0            0            0
# 820tgsjxq7            0            1            0            0            0
# 4ft3gnwmtx            0            1            0            0            0
# bjjt8pjhuk            0            1            0            0            0
# 87mebub9p4            0            1            0            0            0
#
#             language_ja  language_ko  language_other  language_pt  \
# id
# gxn3p5htnn            0            0               0            0
# 820tgsjxq7            0            0               0            0
# 4ft3gnwmtx            0            0               0            0
# bjjt8pjhuk            0            0               0            0
# 87mebub9p4            0            0               0            0
#
#             language_ru  language_zh
# id
# gxn3p5htnn            0            0
# 820tgsjxq7            0            0
# 4ft3gnwmtx            0            0
# bjjt8pjhuk            0            0
# 87mebub9p4            0            0
# language_de       uint8
# language_en       uint8
# language_es       uint8
# language_fr       uint8
# language_it       uint8
# language_ja       uint8
# language_ko       uint8
# language_other    uint8
# language_pt       uint8
# language_ru       uint8
# language_zh       uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             signup_app_Android  signup_app_Moweb  signup_app_Web  \
# id
# gxn3p5htnn                   0                 0               1
# 820tgsjxq7                   0                 0               1
# 4ft3gnwmtx                   0                 0               1
# bjjt8pjhuk                   0                 0               1
# 87mebub9p4                   0                 0               1
#
#             signup_app_iOS
# id
# gxn3p5htnn               0
# 820tgsjxq7               0
# 4ft3gnwmtx               0
# bjjt8pjhuk               0
# 87mebub9p4               0
# signup_app_Android    uint8
# signup_app_Moweb      uint8
# signup_app_Web        uint8
# signup_app_iOS        uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             signup_method_basic  signup_method_facebook  signup_method_google  \
# id
# gxn3p5htnn                    0                       1                     0
# 820tgsjxq7                    0                       1                     0
# 4ft3gnwmtx                    1                       0                     0
# bjjt8pjhuk                    0                       1                     0
# 87mebub9p4                    1                       0                     0
#
#             signup_method_other
# id
# gxn3p5htnn                    0
# 820tgsjxq7                    0
# 4ft3gnwmtx                    0
# bjjt8pjhuk                    0
# 87mebub9p4                    0
# signup_method_basic       uint8
# signup_method_facebook    uint8
# signup_method_google      uint8
# signup_method_other       uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             signup_flow_0  signup_flow_1  signup_flow_2  signup_flow_3  \
# id
# gxn3p5htnn              1              0              0              0
# 820tgsjxq7              1              0              0              0
# 4ft3gnwmtx              0              0              0              1
# bjjt8pjhuk              1              0              0              0
# 87mebub9p4              1              0              0              0
#
#             signup_flow_6  signup_flow_8  signup_flow_12  signup_flow_23  \
# id
# gxn3p5htnn              0              0               0               0
# 820tgsjxq7              0              0               0               0
# 4ft3gnwmtx              0              0               0               0
# bjjt8pjhuk              0              0               0               0
# 87mebub9p4              0              0               0               0
#
#             signup_flow_24  signup_flow_25  signup_flow_other
# id
# gxn3p5htnn               0               0                  0
# 820tgsjxq7               0               0                  0
# 4ft3gnwmtx               0               0                  0
# bjjt8pjhuk               0               0                  0
# 87mebub9p4               0               0                  0
# signup_flow_0        uint8
# signup_flow_1        uint8
# signup_flow_2        uint8
# signup_flow_3        uint8
# signup_flow_6        uint8
# signup_flow_8        uint8
# signup_flow_12       uint8
# signup_flow_23       uint8
# signup_flow_24       uint8
# signup_flow_25       uint8
# signup_flow_other    uint8
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
#             affiliate_channel_api  affiliate_channel_content  \
# id
# gxn3p5htnn                      0                          0
# 820tgsjxq7                      0                          0
# 4ft3gnwmtx                      0                          0
# bjjt8pjhuk                      0                          0
# 87mebub9p4                      0                          0
#
#             affiliate_channel_direct  affiliate_channel_other  \
# id
# gxn3p5htnn                         1                        0
# 820tgsjxq7                         0                        0
# 4ft3gnwmtx                         1                        0
# bjjt8pjhuk                         1                        0
# 87mebub9p4                         1                        0
#
#             affiliate_channel_remarketing  affiliate_channel_sem-brand  \
# id
# gxn3p5htnn                              0                            0
# 820tgsjxq7                              0                            0
# 4ft3gnwmtx                              0                            0
# bjjt8pjhuk                              0                            0
# 87mebub9p4                              0                            0
#
#             affiliate_channel_sem-non-brand  affiliate_channel_seo  \
# id
# gxn3p5htnn                                0                      0
# 820tgsjxq7                                0                      1
# 4ft3gnwmtx                                0                      0
# bjjt8pjhuk                                0                      0
# 87mebub9p4                                0                      0
#
#             affiliate_provider_bing  affiliate_provider_craigslist  ...   \
# id                                                                  ...
# gxn3p5htnn                        0                              0  ...
# 820tgsjxq7                        0                              0  ...
# 4ft3gnwmtx                        0                              0  ...
# bjjt8pjhuk                        0                              0  ...
# 87mebub9p4                        0                              0  ...
#
#             signup_flow_8  signup_flow_12  signup_flow_23  signup_flow_24  \
# id
# gxn3p5htnn              0               0               0               0
# 820tgsjxq7              0               0               0               0
# 4ft3gnwmtx              0               0               0               0
# bjjt8pjhuk              0               0               0               0
# 87mebub9p4              0               0               0               0
#
#             signup_flow_25  signup_flow_other  date_account_created  \
# id
# gxn3p5htnn               0                  0            2010-06-28
# 820tgsjxq7               0                  0            2011-05-25
# 4ft3gnwmtx               0                  0            2010-09-28
# bjjt8pjhuk               0                  0            2011-12-05
# 87mebub9p4               0                  0            2010-09-14
#
#             timestamp_first_active  date_first_booking   age
# id
# gxn3p5htnn          20090319043255                  -1  -1.0
# 820tgsjxq7          20090523174809                  -1  38.0
# 4ft3gnwmtx          20090609231247          2010-08-02  56.0
# bjjt8pjhuk          20091031060129          2012-09-08  42.0
# 87mebub9p4          20091208061105          2010-02-18  41.0
#
# [5 rows x 84 columns]

# %%
for i, period in enumerate(['year', 'month', 'day', 'weekday']):
    print i ,period
# Out:
# 0 year
# 1 month
# 2 day
# 3 weekday

# %%
extracted_vals = np.vstack(features[ACCOUNT_DATE].apply(
    (lambda x: _parse_date(x, DATE_FORMAT))))
for i, period in enumerate(['year', 'month', 'day', 'weekday']):
    features['%s_%s' % (ACCOUNT_DATE, period)] = extracted_vals[:, i]
features.drop(ACCOUNT_DATE, axis=1)
# Out:
#             timestamp_first_active date_first_booking     gender   age  \
# id
# gxn3p5htnn          20090319043255                 -1  -unknown-  -1.0
# 820tgsjxq7          20090523174809                 -1       MALE  38.0
# 4ft3gnwmtx          20090609231247         2010-08-02     FEMALE  56.0
# bjjt8pjhuk          20091031060129         2012-09-08     FEMALE  42.0
# 87mebub9p4          20091208061105         2010-02-18  -unknown-  41.0
# osr2jwljor          20100101215619         2010-01-02  -unknown-  -1.0
# lsw9q7uk0j          20100102012558         2010-01-05     FEMALE  46.0
# 0d01nltbrs          20100103191905         2010-01-13     FEMALE  47.0
# a1vcnhxeij          20100104004211         2010-07-29     FEMALE  50.0
# 6uh8zyj2gn          20100104023758         2010-01-04  -unknown-  46.0
# yuuqmid2rp          20100104194251         2010-01-06     FEMALE  36.0
# om1ss59ys8          20100105051812                 -1     FEMALE  47.0
# k6np330cm1          20100105060859         2010-01-18  -unknown-  -1.0
# dy3rgx56cu          20100105083259                 -1     FEMALE  37.0
# ju3h98ch3w          20100107055820                 -1     FEMALE  36.0
# v4d5rl22px          20100107204555         2010-01-08     FEMALE  33.0
# 2dwbwkx056          20100107215125                 -1  -unknown-  -1.0
# frhre329au          20100107224625         2010-01-09  -unknown-  31.0
# cxlg85pg1r          20100108015641                 -1  -unknown-  -1.0
# gdka1q5ktd          20100110010817         2010-01-10     FEMALE  29.0
# qdubonn3uk          20100110152120         2010-01-18  -unknown-  -1.0
# qsibmuz9sx          20100110220941         2010-01-11       MALE  30.0
# 80f7dwscrn          20100111031438         2010-01-11  -unknown-  40.0
# jha93x042q          20100111224015                 -1  -unknown-  -1.0
# 7i49vnuav6          20100111230808                 -1     FEMALE  40.0
# al8bcetz0g          20100112131444         2010-01-15     FEMALE  26.0
# bjg0m5otl3          20100112155420                 -1  -unknown-  -1.0
# hfrl5gle36          20100112205949         2010-01-22     FEMALE  32.0
# tp6x3md0n4          20100113044650         2010-01-13  -unknown-  35.0
# hql77nu2lk          20100113064333         2010-01-19  -unknown-  37.0
# ...                            ...                ...        ...   ...
# bsv2ev628t          20140930231454                 -1  -unknown-  -1.0
# 06echc56pl          20140930231518                 -1     FEMALE  48.0
# niqgaye2ov          20140930231952                 -1  -unknown-  -1.0
# 61iwzuhw6e          20140930232126                 -1     FEMALE  24.0
# gks02el96u          20140930232237                 -1     FEMALE  32.0
# v4r1161l0r          20140930232253                 -1  -unknown-  -1.0
# p1clbqd0o6          20140930232331                 -1  -unknown-  -1.0
# ozb2z0km6l          20140930232507                 -1  -unknown-  -1.0
# w3e3sp6i70          20140930232551                 -1  -unknown-  -1.0
# q5bxbq0asg          20140930232613                 -1     FEMALE  40.0
# 1xa5t3t0la          20140930233113                 -1       MALE  39.0
# zuvz7gfpjz          20140930233305                 -1  -unknown-  -1.0
# gpusl6ppgf          20140930233535                 -1  -unknown-  -1.0
# gpijioh4eh          20140930233902                 -1       MALE  44.0
# 3ptlvdxss9          20140930234128                 -1  -unknown-  39.0
# f9a1ncjnrg          20140930234425                 -1     FEMALE  34.0
# kofaz2kh70          20140930234515                 -1  -unknown-  -1.0
# 6xrmom7hjo          20140930234551                 -1       MALE  40.0
# cg9wqgnad2          20140930234612                 -1       MALE  27.0
# jg618z94wo          20140930234617                 -1     FEMALE  24.0
# u7lv3glv6y          20140930234703                 -1  -unknown-  -1.0
# o6ofmozucx          20140930234751                 -1       MALE  55.0
# wcw7xggeqp          20140930234904                 -1  -unknown-  34.0
# m22pw2pkxr          20140930235000                 -1       MALE  32.0
# 8yvhec201j          20140930235019                 -1  -unknown-  -1.0
# cv0na2lf5a          20140930235232                 -1  -unknown-  31.0
# zp8xfonng8          20140930235306                 -1  -unknown-  -1.0
# fa6260ziny          20140930235408                 -1  -unknown-  -1.0
# 87k0fy4ugm          20140930235430                 -1  -unknown-  -1.0
# 9uqfg8txu3          20140930235901                 -1     FEMALE  49.0
#
#            signup_method signup_flow language affiliate_channel  \
# id
# gxn3p5htnn      facebook           0       en            direct
# 820tgsjxq7      facebook           0       en               seo
# 4ft3gnwmtx         basic           3       en            direct
# bjjt8pjhuk      facebook           0       en            direct
# 87mebub9p4         basic           0       en            direct
# osr2jwljor         basic           0       en             other
# lsw9q7uk0j         basic           0       en             other
# 0d01nltbrs         basic           0       en            direct
# a1vcnhxeij         basic           0       en             other
# 6uh8zyj2gn         basic           0       en             other
# yuuqmid2rp         basic           0       en             other
# om1ss59ys8         basic           0       en             other
# k6np330cm1         basic           0       en            direct
# dy3rgx56cu         basic           0       en             other
# ju3h98ch3w         basic           0       en             other
# v4d5rl22px         basic           0       en            direct
# 2dwbwkx056         basic           0       en             other
# frhre329au         basic           0       en             other
# cxlg85pg1r         basic           0       en               seo
# gdka1q5ktd         basic           0       en            direct
# qdubonn3uk         basic           0       en            direct
# qsibmuz9sx         basic           0       en            direct
# 80f7dwscrn         basic           0       en               seo
# jha93x042q         basic           0       en             other
# 7i49vnuav6         basic           0       en               seo
# al8bcetz0g         basic           0       en             other
# bjg0m5otl3         basic           0       en             other
# hfrl5gle36         basic           0       en             other
# tp6x3md0n4         basic           0       en            direct
# hql77nu2lk         basic           0       en            direct
# ...                  ...         ...      ...               ...
# bsv2ev628t        google          12       en            direct
# 06echc56pl         basic           0       en            direct
# niqgaye2ov         basic           0       en               seo
# 61iwzuhw6e      facebook          25       en            direct
# gks02el96u      facebook           0       en               seo
# v4r1161l0r         basic           0       en            direct
# p1clbqd0o6         basic          23       en            direct
# ozb2z0km6l         basic          23       en            direct
# w3e3sp6i70         basic           0       en            direct
# q5bxbq0asg      facebook           0       en         sem-brand
# 1xa5t3t0la      facebook           0       en               seo
# zuvz7gfpjz         basic           0       en               seo
# gpusl6ppgf         basic           0       en               seo
# gpijioh4eh         basic           0       en               seo
# 3ptlvdxss9         basic           0       en               seo
# f9a1ncjnrg      facebook          23       en            direct
# kofaz2kh70         basic           0       en               seo
# 6xrmom7hjo      facebook          23       en            direct
# cg9wqgnad2      facebook           0       en            direct
# jg618z94wo      facebook           0       en            direct
# u7lv3glv6y         basic          25       en            direct
# o6ofmozucx         basic           0       en         sem-brand
# wcw7xggeqp         basic           0       en            direct
# m22pw2pkxr         basic           0       en            direct
# 8yvhec201j         basic           0       en               seo
# cv0na2lf5a         basic           0       en            direct
# zp8xfonng8         basic          23       ko            direct
# fa6260ziny         basic           0       de            direct
# 87k0fy4ugm         basic           0       en         sem-brand
# 9uqfg8txu3         basic           0       en             other
#
#            affiliate_provider first_affiliate_tracked signup_app  \
# id
# gxn3p5htnn             direct               untracked        Web
# 820tgsjxq7             google               untracked        Web
# 4ft3gnwmtx             direct               untracked        Web
# bjjt8pjhuk             direct               untracked        Web
# 87mebub9p4             direct               untracked        Web
# osr2jwljor              other                     omg        Web
# lsw9q7uk0j         craigslist               untracked        Web
# 0d01nltbrs             direct                     omg        Web
# a1vcnhxeij         craigslist               untracked        Web
# 6uh8zyj2gn         craigslist                     omg        Web
# yuuqmid2rp         craigslist               untracked        Web
# om1ss59ys8         craigslist               untracked        Web
# k6np330cm1             direct                      -1        Web
# dy3rgx56cu         craigslist                  linked        Web
# ju3h98ch3w         craigslist               untracked        Web
# v4d5rl22px             direct               untracked        Web
# 2dwbwkx056         craigslist                      -1        Web
# frhre329au         craigslist                      -1        Web
# cxlg85pg1r           facebook                      -1        Web
# gdka1q5ktd             direct               untracked        Web
# qdubonn3uk             direct                      -1        Web
# qsibmuz9sx             direct                  linked        Web
# 80f7dwscrn             google               untracked        Web
# jha93x042q         craigslist               untracked        Web
# 7i49vnuav6             google               untracked        Web
# al8bcetz0g         craigslist               untracked        Web
# bjg0m5otl3              other               untracked        Web
# hfrl5gle36         craigslist               untracked        Web
# tp6x3md0n4             direct                      -1        Web
# hql77nu2lk             direct               untracked        Web
# ...                       ...                     ...        ...
# bsv2ev628t             direct               untracked    Android
# 06echc56pl             direct               untracked        Web
# niqgaye2ov             google               untracked        Web
# 61iwzuhw6e             direct               untracked        iOS
# gks02el96u           facebook               untracked        Web
# v4r1161l0r             direct               untracked      Moweb
# p1clbqd0o6             direct               untracked    Android
# ozb2z0km6l             direct               untracked    Android
# w3e3sp6i70             direct                  linked      Moweb
# q5bxbq0asg             google                     omg        Web
# 1xa5t3t0la           facebook               untracked        Web
# zuvz7gfpjz             google               untracked        Web
# gpusl6ppgf             google               untracked        Web
# gpijioh4eh             google                  linked        Web
# 3ptlvdxss9             google                  linked        Web
# f9a1ncjnrg             direct               untracked    Android
# kofaz2kh70             google               untracked        Web
# 6xrmom7hjo             direct               untracked    Android
# cg9wqgnad2             direct               untracked        Web
# jg618z94wo             direct                  linked        Web
# u7lv3glv6y             direct               untracked        iOS
# o6ofmozucx             google                     omg        Web
# wcw7xggeqp             direct               untracked        Web
# m22pw2pkxr             direct                  linked        Web
# 8yvhec201j              yahoo                  linked        Web
# cv0na2lf5a             direct               untracked        Web
# zp8xfonng8             direct               untracked    Android
# fa6260ziny             direct                  linked        Web
# 87k0fy4ugm             google                     omg        Web
# 9uqfg8txu3              other           tracked-other        Web
#
#            first_device_type  first_browser  date_account_created_year  \
# id
# gxn3p5htnn       Mac Desktop         Chrome                       2010
# 820tgsjxq7       Mac Desktop         Chrome                       2011
# 4ft3gnwmtx   Windows Desktop             IE                       2010
# bjjt8pjhuk       Mac Desktop        Firefox                       2011
# 87mebub9p4       Mac Desktop         Chrome                       2010
# osr2jwljor       Mac Desktop         Chrome                       2010
# lsw9q7uk0j       Mac Desktop         Safari                       2010
# 0d01nltbrs       Mac Desktop         Safari                       2010
# a1vcnhxeij       Mac Desktop         Safari                       2010
# 6uh8zyj2gn       Mac Desktop        Firefox                       2010
# yuuqmid2rp       Mac Desktop        Firefox                       2010
# om1ss59ys8            iPhone      -unknown-                       2010
# k6np330cm1     Other/Unknown      -unknown-                       2010
# dy3rgx56cu       Mac Desktop        Firefox                       2010
# ju3h98ch3w            iPhone  Mobile Safari                       2010
# v4d5rl22px   Windows Desktop         Chrome                       2010
# 2dwbwkx056     Other/Unknown      -unknown-                       2010
# frhre329au     Other/Unknown      -unknown-                       2010
# cxlg85pg1r     Other/Unknown      -unknown-                       2010
# gdka1q5ktd       Mac Desktop         Chrome                       2010
# qdubonn3uk     Other/Unknown      -unknown-                       2010
# qsibmuz9sx       Mac Desktop         Chrome                       2010
# 80f7dwscrn            iPhone      -unknown-                       2010
# jha93x042q       Mac Desktop         Safari                       2010
# 7i49vnuav6       Mac Desktop        Firefox                       2010
# al8bcetz0g       Mac Desktop         Chrome                       2010
# bjg0m5otl3     Other/Unknown      -unknown-                       2010
# hfrl5gle36   Desktop (Other)         Chrome                       2010
# tp6x3md0n4     Other/Unknown      -unknown-                       2010
# hql77nu2lk    Android Tablet      -unknown-                       2010
# ...                      ...            ...                        ...
# bsv2ev628t     Android Phone      -unknown-                       2014
# 06echc56pl       Mac Desktop         Safari                       2014
# niqgaye2ov       Mac Desktop        Firefox                       2014
# 61iwzuhw6e            iPhone      -unknown-                       2014
# gks02el96u              iPad  Mobile Safari                       2014
# v4r1161l0r     Android Phone  Chrome Mobile                       2014
# p1clbqd0o6     Android Phone      -unknown-                       2014
# ozb2z0km6l     Android Phone      -unknown-                       2014
# w3e3sp6i70            iPhone  Mobile Safari                       2014
# q5bxbq0asg   Windows Desktop        Firefox                       2014
# 1xa5t3t0la            iPhone  Mobile Safari                       2014
# zuvz7gfpjz       Mac Desktop        Firefox                       2014
# gpusl6ppgf              iPad  Mobile Safari                       2014
# gpijioh4eh       Mac Desktop         Chrome                       2014
# 3ptlvdxss9   Windows Desktop        Firefox                       2014
# f9a1ncjnrg     Android Phone      -unknown-                       2014
# kofaz2kh70       Mac Desktop         Safari                       2014
# 6xrmom7hjo     Android Phone      -unknown-                       2014
# cg9wqgnad2       Mac Desktop        Firefox                       2014
# jg618z94wo            iPhone  Mobile Safari                       2014
# u7lv3glv6y            iPhone      -unknown-                       2014
# o6ofmozucx   Windows Desktop        Firefox                       2014
# wcw7xggeqp       Mac Desktop         Chrome                       2014
# m22pw2pkxr   Windows Desktop         Chrome                       2014
# 8yvhec201j   Windows Desktop         Chrome                       2014
# cv0na2lf5a   Windows Desktop             IE                       2014
# zp8xfonng8     Android Phone      -unknown-                       2014
# fa6260ziny   Windows Desktop        Firefox                       2014
# 87k0fy4ugm       Mac Desktop         Safari                       2014
# 9uqfg8txu3   Windows Desktop         Chrome                       2014
#
#             date_account_created_month  date_account_created_day  \
# id
# gxn3p5htnn                           6                        28
# 820tgsjxq7                           5                        25
# 4ft3gnwmtx                           9                        28
# bjjt8pjhuk                          12                         5
# 87mebub9p4                           9                        14
# osr2jwljor                           1                         1
# lsw9q7uk0j                           1                         2
# 0d01nltbrs                           1                         3
# a1vcnhxeij                           1                         4
# 6uh8zyj2gn                           1                         4
# yuuqmid2rp                           1                         4
# om1ss59ys8                           1                         5
# k6np330cm1                           1                         5
# dy3rgx56cu                           1                         5
# ju3h98ch3w                           1                         7
# v4d5rl22px                           1                         7
# 2dwbwkx056                           1                         7
# frhre329au                           1                         7
# cxlg85pg1r                           1                         8
# gdka1q5ktd                           1                        10
# qdubonn3uk                           1                        10
# qsibmuz9sx                           1                        10
# 80f7dwscrn                           1                        11
# jha93x042q                           1                        11
# 7i49vnuav6                           1                        11
# al8bcetz0g                           1                        12
# bjg0m5otl3                           1                        12
# hfrl5gle36                           1                        12
# tp6x3md0n4                           1                        13
# hql77nu2lk                           1                        13
# ...                                ...                       ...
# bsv2ev628t                           9                        30
# 06echc56pl                           9                        30
# niqgaye2ov                           9                        30
# 61iwzuhw6e                           9                        30
# gks02el96u                           9                        30
# v4r1161l0r                           9                        30
# p1clbqd0o6                           9                        30
# ozb2z0km6l                           9                        30
# w3e3sp6i70                           9                        30
# q5bxbq0asg                           9                        30
# 1xa5t3t0la                           9                        30
# zuvz7gfpjz                           9                        30
# gpusl6ppgf                           9                        30
# gpijioh4eh                           9                        30
# 3ptlvdxss9                           9                        30
# f9a1ncjnrg                           9                        30
# kofaz2kh70                           9                        30
# 6xrmom7hjo                           9                        30
# cg9wqgnad2                           9                        30
# jg618z94wo                           9                        30
# u7lv3glv6y                           9                        30
# o6ofmozucx                           9                        30
# wcw7xggeqp                           9                        30
# m22pw2pkxr                           9                        30
# 8yvhec201j                           9                        30
# cv0na2lf5a                           9                        30
# zp8xfonng8                           9                        30
# fa6260ziny                           9                        30
# 87k0fy4ugm                           9                        30
# 9uqfg8txu3                           9                        30
#
#             date_account_created_weekday
# id
# gxn3p5htnn                             0
# 820tgsjxq7                             2
# 4ft3gnwmtx                             1
# bjjt8pjhuk                             0
# 87mebub9p4                             1
# osr2jwljor                             4
# lsw9q7uk0j                             5
# 0d01nltbrs                             6
# a1vcnhxeij                             0
# 6uh8zyj2gn                             0
# yuuqmid2rp                             0
# om1ss59ys8                             1
# k6np330cm1                             1
# dy3rgx56cu                             1
# ju3h98ch3w                             3
# v4d5rl22px                             3
# 2dwbwkx056                             3
# frhre329au                             3
# cxlg85pg1r                             4
# gdka1q5ktd                             6
# qdubonn3uk                             6
# qsibmuz9sx                             6
# 80f7dwscrn                             0
# jha93x042q                             0
# 7i49vnuav6                             0
# al8bcetz0g                             1
# bjg0m5otl3                             1
# hfrl5gle36                             1
# tp6x3md0n4                             2
# hql77nu2lk                             2
# ...                                  ...
# bsv2ev628t                             1
# 06echc56pl                             1
# niqgaye2ov                             1
# 61iwzuhw6e                             1
# gks02el96u                             1
# v4r1161l0r                             1
# p1clbqd0o6                             1
# ozb2z0km6l                             1
# w3e3sp6i70                             1
# q5bxbq0asg                             1
# 1xa5t3t0la                             1
# zuvz7gfpjz                             1
# gpusl6ppgf                             1
# gpijioh4eh                             1
# 3ptlvdxss9                             1
# f9a1ncjnrg                             1
# kofaz2kh70                             1
# 6xrmom7hjo                             1
# cg9wqgnad2                             1
# jg618z94wo                             1
# u7lv3glv6y                             1
# o6ofmozucx                             1
# wcw7xggeqp                             1
# m22pw2pkxr                             1
# 8yvhec201j                             1
# cv0na2lf5a                             1
# zp8xfonng8                             1
# fa6260ziny                             1
# 87k0fy4ugm                             1
# 9uqfg8txu3                             1
#
# [275547 rows x 17 columns]

# %%
extracted_vals
# Out:
# array([[2010,    6,   28,    0],
#        [2011,    5,   25,    2],
#        [2010,    9,   28,    1],
#        ...,
#        [2014,    9,   30,    1],
#        [2014,    9,   30,    1],
#        [2014,    9,   30,    1]])

# %%
def get_basic_train_test_data():
    """ Load the basic data in a pandas dataframe, and pre-process them. """
    training = pd.read_csv(TRAIN_DATA_BASIC, index_col=0)
    testing = pd.read_csv(TEST_DATA_BASIC, index_col=0)
    labels = training[LABEL].copy()
    training.drop(LABEL, inplace=True, axis=1)
    features = pd.concat((training, testing), axis=0)
    features.fillna(-1, inplace=True)

    # Process all features by removing rare values, appling one-hot-encoding to
    # those that are categorical and extracting numericals from ACCOUNT_DATE.

    remove_rare_values_inplace(features, CATEGORICAL_FEATURES, VALUE_THRESHOLD)
    features = apply_one_hot_encoding(features, CATEGORICAL_FEATURES)
    extract_dates_inplace(features, ACCOUNT_DATE)
    features.drop(UNUSED_DATE_COLUMNS, inplace=True, axis=1)
    return features, labels, training.index, testing.index

# %%
features, labels, training_ids, testing_ids = get_basic_train_test_data()
sessions = pd.read_csv(SESSION_DATA, index_col=0)
features = pd.concat((features, sessions), axis=1)
features.fillna(-1, inplace=True)
# Save data training and testing data.
training = features.ix[training_ids]
testing = features.ix[testing_ids]

# Warning: When saving the data, it's important that the header is True,
# because labels is of type pandas.core.series.Series, while training is of
# type pandas.core.frame.DataFrame, and they have different default values
# for the header argument.

assert set(training.index) == set(labels.index)
training.to_csv(TRAINING_FINAL_CSV_FILE, header=True)
testing.to_csv(TESTING_FINAL_CSV_FILE, header=True)
labels.to_csv(LABELS_FINAL_CSV_FILE, header=True)
# Out:
# /Users/bgg/training_course/lib/python2.7/site-packages/ipykernel/__main__.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
features
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28          20090319043255                 -1
# 820tgsjxq7           2011-05-25          20090523174809                 -1
# 4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 87mebub9p4           2010-09-14          20091208061105         2010-02-18
# osr2jwljor           2010-01-01          20100101215619         2010-01-02
# lsw9q7uk0j           2010-01-02          20100102012558         2010-01-05
# 0d01nltbrs           2010-01-03          20100103191905         2010-01-13
# a1vcnhxeij           2010-01-04          20100104004211         2010-07-29
# 6uh8zyj2gn           2010-01-04          20100104023758         2010-01-04
# yuuqmid2rp           2010-01-04          20100104194251         2010-01-06
# om1ss59ys8           2010-01-05          20100105051812                 -1
# k6np330cm1           2010-01-05          20100105060859         2010-01-18
# dy3rgx56cu           2010-01-05          20100105083259                 -1
# ju3h98ch3w           2010-01-07          20100107055820                 -1
# v4d5rl22px           2010-01-07          20100107204555         2010-01-08
# 2dwbwkx056           2010-01-07          20100107215125                 -1
# frhre329au           2010-01-07          20100107224625         2010-01-09
# cxlg85pg1r           2010-01-08          20100108015641                 -1
# gdka1q5ktd           2010-01-10          20100110010817         2010-01-10
# qdubonn3uk           2010-01-10          20100110152120         2010-01-18
# qsibmuz9sx           2010-01-10          20100110220941         2010-01-11
# 80f7dwscrn           2010-01-11          20100111031438         2010-01-11
# jha93x042q           2010-01-11          20100111224015                 -1
# 7i49vnuav6           2010-01-11          20100111230808                 -1
# al8bcetz0g           2010-01-12          20100112131444         2010-01-15
# bjg0m5otl3           2010-01-12          20100112155420                 -1
# hfrl5gle36           2010-01-12          20100112205949         2010-01-22
# tp6x3md0n4           2010-01-13          20100113044650         2010-01-13
# hql77nu2lk           2010-01-13          20100113064333         2010-01-19
# ...                         ...                     ...                ...
# bsv2ev628t           2014-09-30          20140930231454                 -1
# 06echc56pl           2014-09-30          20140930231518                 -1
# niqgaye2ov           2014-09-30          20140930231952                 -1
# 61iwzuhw6e           2014-09-30          20140930232126                 -1
# gks02el96u           2014-09-30          20140930232237                 -1
# v4r1161l0r           2014-09-30          20140930232253                 -1
# p1clbqd0o6           2014-09-30          20140930232331                 -1
# ozb2z0km6l           2014-09-30          20140930232507                 -1
# w3e3sp6i70           2014-09-30          20140930232551                 -1
# q5bxbq0asg           2014-09-30          20140930232613                 -1
# 1xa5t3t0la           2014-09-30          20140930233113                 -1
# zuvz7gfpjz           2014-09-30          20140930233305                 -1
# gpusl6ppgf           2014-09-30          20140930233535                 -1
# gpijioh4eh           2014-09-30          20140930233902                 -1
# 3ptlvdxss9           2014-09-30          20140930234128                 -1
# f9a1ncjnrg           2014-09-30          20140930234425                 -1
# kofaz2kh70           2014-09-30          20140930234515                 -1
# 6xrmom7hjo           2014-09-30          20140930234551                 -1
# cg9wqgnad2           2014-09-30          20140930234612                 -1
# jg618z94wo           2014-09-30          20140930234617                 -1
# u7lv3glv6y           2014-09-30          20140930234703                 -1
# o6ofmozucx           2014-09-30          20140930234751                 -1
# wcw7xggeqp           2014-09-30          20140930234904                 -1
# m22pw2pkxr           2014-09-30          20140930235000                 -1
# 8yvhec201j           2014-09-30          20140930235019                 -1
# cv0na2lf5a           2014-09-30          20140930235232                 -1
# zp8xfonng8           2014-09-30          20140930235306                 -1
# fa6260ziny           2014-09-30          20140930235408                 -1
# 87k0fy4ugm           2014-09-30          20140930235430                 -1
# 9uqfg8txu3           2014-09-30          20140930235901                 -1
#
#                gender   age signup_method signup_flow language  \
# id
# gxn3p5htnn  -unknown-  -1.0      facebook           0       en
# 820tgsjxq7       MALE  38.0      facebook           0       en
# 4ft3gnwmtx     FEMALE  56.0         basic           3       en
# bjjt8pjhuk     FEMALE  42.0      facebook           0       en
# 87mebub9p4  -unknown-  41.0         basic           0       en
# osr2jwljor  -unknown-  -1.0         basic           0       en
# lsw9q7uk0j     FEMALE  46.0         basic           0       en
# 0d01nltbrs     FEMALE  47.0         basic           0       en
# a1vcnhxeij     FEMALE  50.0         basic           0       en
# 6uh8zyj2gn  -unknown-  46.0         basic           0       en
# yuuqmid2rp     FEMALE  36.0         basic           0       en
# om1ss59ys8     FEMALE  47.0         basic           0       en
# k6np330cm1  -unknown-  -1.0         basic           0       en
# dy3rgx56cu     FEMALE  37.0         basic           0       en
# ju3h98ch3w     FEMALE  36.0         basic           0       en
# v4d5rl22px     FEMALE  33.0         basic           0       en
# 2dwbwkx056  -unknown-  -1.0         basic           0       en
# frhre329au  -unknown-  31.0         basic           0       en
# cxlg85pg1r  -unknown-  -1.0         basic           0       en
# gdka1q5ktd     FEMALE  29.0         basic           0       en
# qdubonn3uk  -unknown-  -1.0         basic           0       en
# qsibmuz9sx       MALE  30.0         basic           0       en
# 80f7dwscrn  -unknown-  40.0         basic           0       en
# jha93x042q  -unknown-  -1.0         basic           0       en
# 7i49vnuav6     FEMALE  40.0         basic           0       en
# al8bcetz0g     FEMALE  26.0         basic           0       en
# bjg0m5otl3  -unknown-  -1.0         basic           0       en
# hfrl5gle36     FEMALE  32.0         basic           0       en
# tp6x3md0n4  -unknown-  35.0         basic           0       en
# hql77nu2lk  -unknown-  37.0         basic           0       en
# ...               ...   ...           ...         ...      ...
# bsv2ev628t  -unknown-  -1.0        google          12       en
# 06echc56pl     FEMALE  48.0         basic           0       en
# niqgaye2ov  -unknown-  -1.0         basic           0       en
# 61iwzuhw6e     FEMALE  24.0      facebook          25       en
# gks02el96u     FEMALE  32.0      facebook           0       en
# v4r1161l0r  -unknown-  -1.0         basic           0       en
# p1clbqd0o6  -unknown-  -1.0         basic          23       en
# ozb2z0km6l  -unknown-  -1.0         basic          23       en
# w3e3sp6i70  -unknown-  -1.0         basic           0       en
# q5bxbq0asg     FEMALE  40.0      facebook           0       en
# 1xa5t3t0la       MALE  39.0      facebook           0       en
# zuvz7gfpjz  -unknown-  -1.0         basic           0       en
# gpusl6ppgf  -unknown-  -1.0         basic           0       en
# gpijioh4eh       MALE  44.0         basic           0       en
# 3ptlvdxss9  -unknown-  39.0         basic           0       en
# f9a1ncjnrg     FEMALE  34.0      facebook          23       en
# kofaz2kh70  -unknown-  -1.0         basic           0       en
# 6xrmom7hjo       MALE  40.0      facebook          23       en
# cg9wqgnad2       MALE  27.0      facebook           0       en
# jg618z94wo     FEMALE  24.0      facebook           0       en
# u7lv3glv6y  -unknown-  -1.0         basic          25       en
# o6ofmozucx       MALE  55.0         basic           0       en
# wcw7xggeqp  -unknown-  34.0         basic           0       en
# m22pw2pkxr       MALE  32.0         basic           0       en
# 8yvhec201j  -unknown-  -1.0         basic           0       en
# cv0na2lf5a  -unknown-  31.0         basic           0       en
# zp8xfonng8  -unknown-  -1.0         basic          23       ko
# fa6260ziny  -unknown-  -1.0         basic           0       de
# 87k0fy4ugm  -unknown-  -1.0         basic           0       en
# 9uqfg8txu3     FEMALE  49.0         basic           0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
# osr2jwljor             other              other                     omg
# lsw9q7uk0j             other         craigslist               untracked
# 0d01nltbrs            direct             direct                     omg
# a1vcnhxeij             other         craigslist               untracked
# 6uh8zyj2gn             other         craigslist                     omg
# yuuqmid2rp             other         craigslist               untracked
# om1ss59ys8             other         craigslist               untracked
# k6np330cm1            direct             direct                      -1
# dy3rgx56cu             other         craigslist                  linked
# ju3h98ch3w             other         craigslist               untracked
# v4d5rl22px            direct             direct               untracked
# 2dwbwkx056             other         craigslist                      -1
# frhre329au             other         craigslist                      -1
# cxlg85pg1r               seo           facebook                      -1
# gdka1q5ktd            direct             direct               untracked
# qdubonn3uk            direct             direct                      -1
# qsibmuz9sx            direct             direct                  linked
# 80f7dwscrn               seo             google               untracked
# jha93x042q             other         craigslist               untracked
# 7i49vnuav6               seo             google               untracked
# al8bcetz0g             other         craigslist               untracked
# bjg0m5otl3             other              other               untracked
# hfrl5gle36             other         craigslist               untracked
# tp6x3md0n4            direct             direct                      -1
# hql77nu2lk            direct             direct               untracked
# ...                      ...                ...                     ...
# bsv2ev628t            direct             direct               untracked
# 06echc56pl            direct             direct               untracked
# niqgaye2ov               seo             google               untracked
# 61iwzuhw6e            direct             direct               untracked
# gks02el96u               seo           facebook               untracked
# v4r1161l0r            direct             direct               untracked
# p1clbqd0o6            direct             direct               untracked
# ozb2z0km6l            direct             direct               untracked
# w3e3sp6i70            direct             direct                  linked
# q5bxbq0asg         sem-brand             google                     omg
# 1xa5t3t0la               seo           facebook               untracked
# zuvz7gfpjz               seo             google               untracked
# gpusl6ppgf               seo             google               untracked
# gpijioh4eh               seo             google                  linked
# 3ptlvdxss9               seo             google                  linked
# f9a1ncjnrg            direct             direct               untracked
# kofaz2kh70               seo             google               untracked
# 6xrmom7hjo            direct             direct               untracked
# cg9wqgnad2            direct             direct               untracked
# jg618z94wo            direct             direct                  linked
# u7lv3glv6y            direct             direct               untracked
# o6ofmozucx         sem-brand             google                     omg
# wcw7xggeqp            direct             direct               untracked
# m22pw2pkxr            direct             direct                  linked
# 8yvhec201j               seo              yahoo                  linked
# cv0na2lf5a            direct             direct               untracked
# zp8xfonng8            direct             direct               untracked
# fa6260ziny            direct             direct                  linked
# 87k0fy4ugm         sem-brand             google                     omg
# 9uqfg8txu3             other              other           tracked-other
#
#            signup_app first_device_type  first_browser  \
# id
# gxn3p5htnn        Web       Mac Desktop         Chrome
# 820tgsjxq7        Web       Mac Desktop         Chrome
# 4ft3gnwmtx        Web   Windows Desktop             IE
# bjjt8pjhuk        Web       Mac Desktop        Firefox
# 87mebub9p4        Web       Mac Desktop         Chrome
# osr2jwljor        Web       Mac Desktop         Chrome
# lsw9q7uk0j        Web       Mac Desktop         Safari
# 0d01nltbrs        Web       Mac Desktop         Safari
# a1vcnhxeij        Web       Mac Desktop         Safari
# 6uh8zyj2gn        Web       Mac Desktop        Firefox
# yuuqmid2rp        Web       Mac Desktop        Firefox
# om1ss59ys8        Web            iPhone      -unknown-
# k6np330cm1        Web     Other/Unknown      -unknown-
# dy3rgx56cu        Web       Mac Desktop        Firefox
# ju3h98ch3w        Web            iPhone  Mobile Safari
# v4d5rl22px        Web   Windows Desktop         Chrome
# 2dwbwkx056        Web     Other/Unknown      -unknown-
# frhre329au        Web     Other/Unknown      -unknown-
# cxlg85pg1r        Web     Other/Unknown      -unknown-
# gdka1q5ktd        Web       Mac Desktop         Chrome
# qdubonn3uk        Web     Other/Unknown      -unknown-
# qsibmuz9sx        Web       Mac Desktop         Chrome
# 80f7dwscrn        Web            iPhone      -unknown-
# jha93x042q        Web       Mac Desktop         Safari
# 7i49vnuav6        Web       Mac Desktop        Firefox
# al8bcetz0g        Web       Mac Desktop         Chrome
# bjg0m5otl3        Web     Other/Unknown      -unknown-
# hfrl5gle36        Web   Desktop (Other)         Chrome
# tp6x3md0n4        Web     Other/Unknown      -unknown-
# hql77nu2lk        Web    Android Tablet      -unknown-
# ...               ...               ...            ...
# bsv2ev628t    Android     Android Phone      -unknown-
# 06echc56pl        Web       Mac Desktop         Safari
# niqgaye2ov        Web       Mac Desktop        Firefox
# 61iwzuhw6e        iOS            iPhone      -unknown-
# gks02el96u        Web              iPad  Mobile Safari
# v4r1161l0r      Moweb     Android Phone  Chrome Mobile
# p1clbqd0o6    Android     Android Phone      -unknown-
# ozb2z0km6l    Android     Android Phone      -unknown-
# w3e3sp6i70      Moweb            iPhone  Mobile Safari
# q5bxbq0asg        Web   Windows Desktop        Firefox
# 1xa5t3t0la        Web            iPhone  Mobile Safari
# zuvz7gfpjz        Web       Mac Desktop        Firefox
# gpusl6ppgf        Web              iPad  Mobile Safari
# gpijioh4eh        Web       Mac Desktop         Chrome
# 3ptlvdxss9        Web   Windows Desktop        Firefox
# f9a1ncjnrg    Android     Android Phone      -unknown-
# kofaz2kh70        Web       Mac Desktop         Safari
# 6xrmom7hjo    Android     Android Phone      -unknown-
# cg9wqgnad2        Web       Mac Desktop        Firefox
# jg618z94wo        Web            iPhone  Mobile Safari
# u7lv3glv6y        iOS            iPhone      -unknown-
# o6ofmozucx        Web   Windows Desktop        Firefox
# wcw7xggeqp        Web       Mac Desktop         Chrome
# m22pw2pkxr        Web   Windows Desktop         Chrome
# 8yvhec201j        Web   Windows Desktop         Chrome
# cv0na2lf5a        Web   Windows Desktop             IE
# zp8xfonng8    Android     Android Phone      -unknown-
# fa6260ziny        Web   Windows Desktop        Firefox
# 87k0fy4ugm        Web       Mac Desktop         Safari
# 9uqfg8txu3        Web   Windows Desktop         Chrome
#
#             date_account_created_year  date_account_created_month  \
# id
# gxn3p5htnn                       2010                           6
# 820tgsjxq7                       2011                           5
# 4ft3gnwmtx                       2010                           9
# bjjt8pjhuk                       2011                          12
# 87mebub9p4                       2010                           9
# osr2jwljor                       2010                           1
# lsw9q7uk0j                       2010                           1
# 0d01nltbrs                       2010                           1
# a1vcnhxeij                       2010                           1
# 6uh8zyj2gn                       2010                           1
# yuuqmid2rp                       2010                           1
# om1ss59ys8                       2010                           1
# k6np330cm1                       2010                           1
# dy3rgx56cu                       2010                           1
# ju3h98ch3w                       2010                           1
# v4d5rl22px                       2010                           1
# 2dwbwkx056                       2010                           1
# frhre329au                       2010                           1
# cxlg85pg1r                       2010                           1
# gdka1q5ktd                       2010                           1
# qdubonn3uk                       2010                           1
# qsibmuz9sx                       2010                           1
# 80f7dwscrn                       2010                           1
# jha93x042q                       2010                           1
# 7i49vnuav6                       2010                           1
# al8bcetz0g                       2010                           1
# bjg0m5otl3                       2010                           1
# hfrl5gle36                       2010                           1
# tp6x3md0n4                       2010                           1
# hql77nu2lk                       2010                           1
# ...                               ...                         ...
# bsv2ev628t                       2014                           9
# 06echc56pl                       2014                           9
# niqgaye2ov                       2014                           9
# 61iwzuhw6e                       2014                           9
# gks02el96u                       2014                           9
# v4r1161l0r                       2014                           9
# p1clbqd0o6                       2014                           9
# ozb2z0km6l                       2014                           9
# w3e3sp6i70                       2014                           9
# q5bxbq0asg                       2014                           9
# 1xa5t3t0la                       2014                           9
# zuvz7gfpjz                       2014                           9
# gpusl6ppgf                       2014                           9
# gpijioh4eh                       2014                           9
# 3ptlvdxss9                       2014                           9
# f9a1ncjnrg                       2014                           9
# kofaz2kh70                       2014                           9
# 6xrmom7hjo                       2014                           9
# cg9wqgnad2                       2014                           9
# jg618z94wo                       2014                           9
# u7lv3glv6y                       2014                           9
# o6ofmozucx                       2014                           9
# wcw7xggeqp                       2014                           9
# m22pw2pkxr                       2014                           9
# 8yvhec201j                       2014                           9
# cv0na2lf5a                       2014                           9
# zp8xfonng8                       2014                           9
# fa6260ziny                       2014                           9
# 87k0fy4ugm                       2014                           9
# 9uqfg8txu3                       2014                           9
#
#             date_account_created_day  date_account_created_weekday
# id
# gxn3p5htnn                        28                             0
# 820tgsjxq7                        25                             2
# 4ft3gnwmtx                        28                             1
# bjjt8pjhuk                         5                             0
# 87mebub9p4                        14                             1
# osr2jwljor                         1                             4
# lsw9q7uk0j                         2                             5
# 0d01nltbrs                         3                             6
# a1vcnhxeij                         4                             0
# 6uh8zyj2gn                         4                             0
# yuuqmid2rp                         4                             0
# om1ss59ys8                         5                             1
# k6np330cm1                         5                             1
# dy3rgx56cu                         5                             1
# ju3h98ch3w                         7                             3
# v4d5rl22px                         7                             3
# 2dwbwkx056                         7                             3
# frhre329au                         7                             3
# cxlg85pg1r                         8                             4
# gdka1q5ktd                        10                             6
# qdubonn3uk                        10                             6
# qsibmuz9sx                        10                             6
# 80f7dwscrn                        11                             0
# jha93x042q                        11                             0
# 7i49vnuav6                        11                             0
# al8bcetz0g                        12                             1
# bjg0m5otl3                        12                             1
# hfrl5gle36                        12                             1
# tp6x3md0n4                        13                             2
# hql77nu2lk                        13                             2
# ...                              ...                           ...
# bsv2ev628t                        30                             1
# 06echc56pl                        30                             1
# niqgaye2ov                        30                             1
# 61iwzuhw6e                        30                             1
# gks02el96u                        30                             1
# v4r1161l0r                        30                             1
# p1clbqd0o6                        30                             1
# ozb2z0km6l                        30                             1
# w3e3sp6i70                        30                             1
# q5bxbq0asg                        30                             1
# 1xa5t3t0la                        30                             1
# zuvz7gfpjz                        30                             1
# gpusl6ppgf                        30                             1
# gpijioh4eh                        30                             1
# 3ptlvdxss9                        30                             1
# f9a1ncjnrg                        30                             1
# kofaz2kh70                        30                             1
# 6xrmom7hjo                        30                             1
# cg9wqgnad2                        30                             1
# jg618z94wo                        30                             1
# u7lv3glv6y                        30                             1
# o6ofmozucx                        30                             1
# wcw7xggeqp                        30                             1
# m22pw2pkxr                        30                             1
# 8yvhec201j                        30                             1
# cv0na2lf5a                        30                             1
# zp8xfonng8                        30                             1
# fa6260ziny                        30                             1
# 87k0fy4ugm                        30                             1
# 9uqfg8txu3                        30                             1
#
# [275547 rows x 18 columns]

# %%
training.head()
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28          20090319043255                NaN
# 820tgsjxq7           2011-05-25          20090523174809                NaN
# 4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome
# 820tgsjxq7        Web       Mac Desktop        Chrome
# 4ft3gnwmtx        Web   Windows Desktop            IE
# bjjt8pjhuk        Web       Mac Desktop       Firefox
# 87mebub9p4        Web       Mac Desktop        Chrome

# %%
labels.head()
# Out:
# id
# gxn3p5htnn      NDF
# 820tgsjxq7      NDF
# 4ft3gnwmtx       US
# bjjt8pjhuk    other
# 87mebub9p4       US
# Name: country_destination, dtype: object

# %% [markdown]
# # Prediction

# %%
DEPTH_XGB, ESTIMATORS_XGB, LEARNING_XGB, SUBSAMPLE_XGB, COLSAMPLE_XGB = (
    7, 60, 0.2, 0.7, 0.6)                # XGBoost parameters.

ESTIMATORS_RF, CRITERION_RF, DEPTH_RF, MIN_LEAF_RF, JOBS_RF = (
    500, 'gini', 20, 8, 30)              # RandomForestClassifier parameters.
FRESH_DATA_YEAR = 2014                   # Year when data is considered fresh.
SUBMISSION_CSV = 'data/airbnb/final_prediction.csv'  # Where to store the predictions.

# Tunning ensemble members. The votes show the importnce of each classfier
# in the final prediction.

XGB_ALL_VOTE, RF_ALL_VOTE, XGB_FRESH_VOTE, RF_FRESH_VOTE = (5, 2, 10, 4)

# %%
def perform_prediction(training, labels, testing, xgb_votes, rf_votes):
    """ Perform prediction using a combination of XGB and RandomForests. """
    predictions = np.zeros((len(testing), len(set(labels))))
    # Predictions using xgboost.
    for i in range(xgb_votes):
        print 'XGB vote %d' % i
        xgb = XGBClassifier(
            max_depth=DEPTH_XGB, learning_rate=LEARNING_XGB,
            n_estimators=ESTIMATORS_XGB, objective='multi:softprob',
            subsample=SUBSAMPLE_XGB, colsample_bytree=COLSAMPLE_XGB)
        xgb.fit(training, labels)
        predictions += xgb.predict_proba(testing)
    # Predictions using RandomForestClassifier.
    for i in range(rf_votes):
        print 'RandomForest vote %d' % i
        rand_forest = RandomForestClassifier(
            n_estimators=ESTIMATORS_RF, criterion=CRITERION_RF, n_jobs=JOBS_RF,
            max_depth=DEPTH_RF, min_samples_leaf=MIN_LEAF_RF, bootstrap=True)
        rand_forest.fit(training, labels)
        predictions += rand_forest.predict_proba(testing)
    return predictions

# %%
train_df = pd.read_csv(TRAINING_FINAL_CSV_FILE, index_col=0)
labels_df = pd.read_csv(LABELS_FINAL_CSV_FILE, index_col=0)
test_df = pd.read_csv(TESTING_FINAL_CSV_FILE, index_col=0)
assert set(train_df.index) == set(labels_df.index)

encoder = LabelEncoder()
encoder.fit(labels_df[LABEL])
predictions = np.zeros((len(test_df), len(encoder.classes_)))

# Use the full data set for the prediction.
labels = encoder.transform(labels_df[LABEL])
predictions += perform_prediction(
    train_df, labels, test_df, XGB_ALL_VOTE, RF_ALL_VOTE)

# Use only "fresh" data for prediction. Fresh data, are considered those
# that are an ACCOUNT_DATE_YEAR equal or higher than FRESH_DATA_YEAR.

train_fresh = train_df[train_df[ACCOUNT_DATE_YEAR] >= FRESH_DATA_YEAR]
labels_fresh = encoder.transform(labels_df.ix[train_fresh.index][LABEL])
predictions += perform_prediction(
    train_fresh, labels_fresh, test_df, XGB_FRESH_VOTE, RF_FRESH_VOTE)

# Use the 5 classes with highest scores.
ids, countries = ([], [])
for i in range(len(test_df)):
    idx = test_df.index[i]
    ids += [idx] * 5
    countries += encoder.inverse_transform(
        np.argsort(predictions[i])[::-1])[:5].tolist()

# Save prediction in CSV file.
sub = pd.DataFrame(
    np.column_stack((ids, countries)), columns=['id', 'country'])
sub.to_csv(SUBMISSION_CSV, index=False)
# Out:
# XGB vote 0
# XGB vote 1
# XGB vote 2
# XGB vote 3
# XGB vote 4
# RandomForest vote 0
# RandomForest vote 1
# /Users/bgg/training_course/lib/python2.7/site-packages/ipykernel/__main__.py:19: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# XGB vote 0
# XGB vote 1
# XGB vote 2
# XGB vote 3
# XGB vote 4
# XGB vote 5
# XGB vote 6
# XGB vote 7
# XGB vote 8
# XGB vote 9
# RandomForest vote 0
# RandomForest vote 1
# RandomForest vote 2
# RandomForest vote 3

# %%
sub.head()
# Out:
#            id country
# 0  5uwns89zht     NDF
# 1  5uwns89zht      US
# 2  5uwns89zht   other
# 3  5uwns89zht      IT
# 4  5uwns89zht      FR
